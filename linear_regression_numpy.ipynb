# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Random data: x is size, y is color value
np.random.seed(42)
x = 2 * np.random.rand(100, 1)
y = 4 + 3 * x + np.random.randn(100, 1)  # y = 4 + 3x + noise
# Add bias (1s) to x for intercept
X_b = np.c_[np.ones((100, 1)), x]  

# Initialize weights randomly
theta = np.random.randn(2, 1)  

# Gradient descent settings
learning_rate = 0.1
iterations = 1000

for i in range(iterations):
    gradients = 2/100 * X_b.T.dot(X_b.dot(theta) - y)
    theta = theta - learning_rate * gradients

print(f"Learned theta (b, m): {theta}")
# Predict using learned model
x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2, 1)), x_new]
y_predict = x_new_b.dot(theta)

# Plot
plt.plot(x_new, y_predict, "r-", label="Prediction Line")
plt.plot(x, y, "b.", label="Data Points")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Learned theta (b, m): [[4.21509616]
#  [2.77011339]]
